# %% [markdown]
# # Jobsheet 6 : Abstract Base Class (ABC) dan Interface

# %% [markdown]
# ### Praktikum 01: Mendefinisikan Kelas Abstrak Sederhana

# %%
from abc import ABC, abstractmethod

class KendaraanAbstrak(ABC):
    def __init__(self, merk):
        self.merk = merk
        print(f"Inisialisasi KendaraanAbstrak dengan merk: {self.merk}")

    def info_merk(self):
        print(f"Merk kendaraan ini adalah {self.merk}.")

    @abstractmethod
    def start_mesin(self):
        pass

    @abstractmethod
    def stop_mesin(self):
        pass

class Mobil(KendaraanAbstrak):
    def start_mesin(self):
        print(f"Mesin mobil {self.merk} dinyalakan.")

    def stop_mesin(self):
        print(f"Mesin mobil {self.merk} dimatikan.")

mobil_contoh = Mobil("Toyota")
mobil_contoh.info_merk()
mobil_contoh.start_mesin()
mobil_contoh.stop_mesin()
# Out:
# Inisialisasi KendaraanAbstrak dengan merk: Toyota
# Merk kendaraan ini adalah Toyota.
# Mesin mobil Toyota dinyalakan.
# Mesin mobil Toyota dimatikan.

# %% [markdown]
# ### Praktikum 02: Mencoba Instansiasi Kelas Abstrak

# %%
from abc import ABC, abstractmethod

class MediaAbstrak(ABC):
    def __init__(self, judul):
        self.judul = judul
        print(f"Inisialisasi MediaAbstrak dengan judul: {self.judul}")

    @abstractmethod
    def play(self):
        pass

    @abstractmethod
    def stop(self):
        pass

try:
    media = MediaAbstrak("Konten Abstrak")
except TypeError as e:
    print(f"\nGAGAL membuat objek!")
    print(f"Error yang muncul: {e}")
# Out:
# GAGAL membuat objek!
# Error yang muncul: Can't instantiate abstract class MediaAbstrak without an implementation for abstract methods 'play', 'stop'

# %% [markdown]
# ### Praktikum 03: Membuat Subclass Konkret - Alat Pembayaran

# %%
from abc import ABC, abstractmethod
import random

class AlatPembayaranAbstrak(ABC):
    def __init__(self, nama_metode):
        self.nama_metode = nama_metode
        print(f"Inisialisasi alat pembayaran: {self.nama_metode}")

    def info(self):
        print(f"Metode Pembayaran: {self.nama_metode}")

    @abstractmethod
    def proses_pembayaran(self, jumlah):
        pass

class KartuKredit(AlatPembayaranAbstrak):
    def __init__(self, nomor_kartu, nama_pemilik):
        super().__init__("Kartu Kredit")
        self.nomor_kartu = nomor_kartu[-4:]
        self.nama_pemilik = nama_pemilik
        print(f" -> Kartu Kredit ************{self.nomor_kartu} ({self.nama_pemilik}) siap.")

    def proses_pembayaran(self, jumlah):
        print(f" Memproses pembayaran {jumlah} via Kartu Kredit ************{self.nomor_kartu}...")
        berhasil = random.choice([True, False])
        if berhasil:
            print(" Pembayaran Kartu Kredit Berhasil.")
            return True
        else:
            print(" Pembayaran Kartu Kredit Gagal.")
            return False

class DompetDigital(AlatPembayaranAbstrak):
    def __init__(self, nomor_telepon, nama_provider):
        super().__init__(f"Dompet Digital ({nama_provider})")
        self.nomor_telepon = nomor_telepon
        self.saldo = random.randint(50000, 500000)
        print(f" -> Dompet Digital {self.nomor_telepon} siap (Saldo: {self.saldo}).")

    def proses_pembayaran(self, jumlah):
        print(f" Memproses pembayaran {jumlah} via Dompet Digital {self.nomor_telepon}...")
        if jumlah < self.saldo:
            self.saldo -= jumlah
            print(" Pembayaran Dompet Digital Berhasil.")
            print(f" Saldo tersisa: {self.saldo}")
            return True
        else:
            print(" Pembayaran Dompet Digital Gagal.")
            return False

kartu_bca = KartuKredit("1234-5678-9012-3456", "Budi Cahyono")
gopay = DompetDigital("08123456789", "GoPay")

kartu_bca.proses_pembayaran(150000)
gopay.proses_pembayaran(75000)
# Out:
# Inisialisasi alat pembayaran: Kartu Kredit
#  -> Kartu Kredit ************3456 (Budi Cahyono) siap.
# Inisialisasi alat pembayaran: Dompet Digital (GoPay)
#  -> Dompet Digital 08123456789 siap (Saldo: 455943).
#  Memproses pembayaran 150000 via Kartu Kredit ************3456...
#  Pembayaran Kartu Kredit Gagal.
#  Memproses pembayaran 75000 via Dompet Digital 08123456789...
#  Pembayaran Dompet Digital Berhasil.
#  Saldo tersisa: 380943
# True

# %% [markdown]
# ### Praktikum 04: Menggunakan Kelas Abstrak untuk Polimorfisme - Dokumen

# %%
from abc import ABC, abstractmethod
import time

class DokumenAbstrak(ABC):
    def __init__(self, nama_file):
        self.nama_file = nama_file
        print(f"Inisialisasi Dokumen: {self.nama_file}")

    def info_file(self):
        print(f"Nama File: {self.nama_file}")

    @abstractmethod
    def cetak(self):
        pass

    @abstractmethod
    def simpan(self):
        pass

class DokumenTeks(DokumenAbstrak):
    def __init__(self, nama_file, isi_teks):
        super().__init__(nama_file)
        self.isi_teks = isi_teks
        print(" -> Tipe: Dokumen Teks")

    def cetak(self):
        print(f"Mencetak Dokumen Teks '{self.nama_file}':")
        print("===============")
        print(self.isi_teks)
        print("===============")

    def simpan(self):
        print(f"Menyimpan Dokumen Teks '{self.nama_file}' ke disk...")
        time.sleep(0.2)
        print(" -> Berhasil disimpan.")

class Spreadsheet(DokumenAbstrak):
    def __init__(self, nama_file, jumlah_baris, jumlah_kolom):
        super().__init__(nama_file)
        self.baris = jumlah_baris
        self.kolom = jumlah_kolom
        print(" -> Tipe: Spreadsheet")

    def cetak(self):
        print(f"Mencetak Spreadsheet '{self.nama_file}' ({self.baris} baris x {self.kolom} kolom)...")
        print(" (Menampilkan pratinjau...)")

    def simpan(self):
        print(f"Menyimpan Spreadsheet '{self.nama_file}' ke format .xlsx...")
        time.sleep(0.3)
        print(" -> Berhasil disimpan.")

def proses_dokumen(daftar_dokumen):
    print("\n======= MEMPROSES SEMUA DOKUMEN =======")
    for doc in daftar_dokumen:
        doc.cetak()
        doc.simpan()

dok1 = DokumenTeks("laporan.txt", "Ini adalah isi laporan singkat.")
dok2 = Spreadsheet("data_penjualan.xlsx", 200, 15)
koleksi_dokumen = [dok1, dok2]

proses_dokumen(koleksi_dokumen)
# Out:
# Inisialisasi Dokumen: laporan.txt
#  -> Tipe: Dokumen Teks
# Inisialisasi Dokumen: data_penjualan.xlsx
#  -> Tipe: Spreadsheet
#
# ======= MEMPROSES SEMUA DOKUMEN =======
# Mencetak Dokumen Teks 'laporan.txt':
# ===============
# Ini adalah isi laporan singkat.
# ===============
# Menyimpan Dokumen Teks 'laporan.txt' ke disk...
#  -> Berhasil disimpan.
# Mencetak Spreadsheet 'data_penjualan.xlsx' (200 baris x 15 kolom)...
#  (Menampilkan pratinjau...)
# Menyimpan Spreadsheet 'data_penjualan.xlsx' ke format .xlsx...
#  -> Berhasil disimpan.

# %% [markdown]
# ### Praktikum 05: Kelas Abstrak dengan Metode Konkret dan Abstrak

# %%
from abc import ABC, abstractmethod
import math

class BangunDatarAbstrak(ABC):
    def __init__(self, nama):
        self._nama = nama
        print(f"Inisialisasi BangunDatarAbstrak: {self._nama}")

    @property
    def nama(self):
        return self._nama

    def info_lengkap(self):
        print(f"\n--- Info Lengkap: {self.nama} ---")
        luas = self.hitung_luas()
        print(f" Luas : {luas:.2f}")
        keliling = self.hitung_keliling()
        print(f" Keliling : {keliling:.2f}")

    @abstractmethod
    def hitung_luas(self):
        pass

    @abstractmethod
    def hitung_keliling(self):
        pass

class Lingkaran(BangunDatarAbstrak):
    def __init__(self, radius):
        super().__init__("Lingkaran")
        if radius < 0:
            raise ValueError("Radius tidak boleh negatif")
        self.radius = radius
        print(f" -> Lingkaran dibuat (Radius: {self.radius}).")

    def hitung_luas(self):
        return math.pi * (self.radius ** 2)

    def hitung_keliling(self):
        return 2 * math.pi * self.radius

lingkaran_A = Lingkaran(10)
lingkaran_A.info_lengkap()
# Out:
# Inisialisasi BangunDatarAbstrak: Lingkaran
#  -> Lingkaran dibuat (Radius: 10).
#
# --- Info Lengkap: Lingkaran ---
#  Luas : 314.16
#  Keliling : 62.83

# %% [markdown]
# ### Praktikum 06: Properti Abstrak - Elemen Grafis

# %%
from abc import ABC, abstractmethod

class ElemenGrafis(ABC):
    def __init__(self, id_elemen, warna):
        self._id = id_elemen
        self.warna = warna
        print(f" [ElemenGrafis init] Membuat elemen dengan ID: {id_elemen}")

    @property
    def id_elemen(self):
        return self._id

    @property
    @abstractmethod
    def posisi(self):
        pass

    @posisi.setter
    @abstractmethod
    def posisi(self, koordinat_baru):
        pass

    @abstractmethod
    def gambar(self):
        pass

    def info_warna(self):
        print(f" [ElemenGrafis info warna] Warna elemen {self.id_elemen}: {self.warna}")

class Kotak(ElemenGrafis):
    def __init__(self, id_elemen, warna, x=0, y=0, lebar=10, tinggi=10):
        super().__init__(id_elemen, warna)
        self._x = x
        self._y = y
        self.lebar = lebar
        self.tinggi = tinggi
        print(f" [Kotak init] Menginisialisasi Kotak ID: {self.id_elemen}")

    @property
    def posisi(self):
        return (self._x, self._y)

    @posisi.setter
    def posisi(self, koordinat_baru):
        if isinstance(koordinat_baru, tuple) and len(koordinat_baru) == 2:
            self._x = koordinat_baru[0]
            self._y = koordinat_baru[1]
            print(f" -> Posisi Kotak {self.id_elemen} berhasil diubah ke {self._x}, {self._y}")
        else:
            print(" -> Gagal: Posisi harus berupa tuple (x, y).")

    def gambar(self):
        print(f" [Kotak gambar] Menggambar Kotak '{self.id_elemen}' warna {self.warna} dengan ukuran {self.lebar}x{self.tinggi} di ({self._x}, {self._y})")

kotak1 = Kotak("KotakA", "Merah", x=5, y=10)
kotak1.posisi = (50, 60)
kotak1.gambar()
kotak1.info_warna()
# Out:
#  [ElemenGrafis init] Membuat elemen dengan ID: KotakA
#  [Kotak init] Menginisialisasi Kotak ID: KotakA
#  -> Posisi Kotak KotakA berhasil diubah ke 50, 60
#  [Kotak gambar] Menggambar Kotak 'KotakA' warna Merah dengan ukuran 10x10 di (50, 60)
#  [ElemenGrafis info warna] Warna elemen KotakA: Merah

# %% [markdown]
# ### Penugasan : Membuat Program dengan Menggunakan Konsep Abstract Base Class

# %%
from abc import ABC, abstractmethod

# a) Membuat Kelas Abstrak (Senjata)
class Senjata(ABC):
    def __init__(self, nama):
        self.nama = nama  # [cite: 1244, 1245]

    @abstractmethod
    def serang(self):  # [cite: 1246]
        pass

    @property
    @abstractmethod
    def ammo_atau_daya_tahan(self):  # [cite: 1248, 1249, 1250]
        pass

    def info_nama(self):  # [cite: 1251]
        print(f"Nama Senjata: {self.nama}")

# b) Membuat Kelas Anak Konkret 1 (Pedang)
class Pedang(Senjata):
    def __init__(self, nama, panjang_bilah):
        super().__init__(nama)  # [cite: 1257]
        self.panjang_bilah = panjang_bilah  # [cite: 1256]

    def serang(self):  # [cite: 1261]
        print(f"Pedang {self.nama} menebas dengan bilah sepanjang {self.panjang_bilah} cm!")

    @property
    def ammo_atau_daya_tahan(self):  # [cite: 1263]
        return "Daya tahan tinggi"

# b) Membuat Kelas Anak Konkret 2 (Panah)
class Panah(Senjata):
    def __init__(self, nama, jumlah_anak_panah):
        super().__init__(nama)  # [cite: 1269]
        self._jumlah_anak_panah = jumlah_anak_panah  # [cite: 1268]

    def serang(self):  # [cite: 1270]
        if self._jumlah_anak_panah > 0:
            self._jumlah_anak_panah -= 1
            print(f"Panah {self.nama} melesat! Sisa anak panah: {self._jumlah_anak_panah}.")
        else:
            print(f"Amunisi Panah {self.nama} habis!")

    @property
    def ammo_atau_daya_tahan(self):  # [cite: 1272, 1273]
        return self._jumlah_anak_panah

    @ammo_atau_daya_tahan.setter
    def ammo_atau_daya_tahan(self, value): # [cite: 1273, 1274]
        self._jumlah_anak_panah = value

# c) Kode Utama
if __name__ == "__main__":
    # Membuat objek
    pedang_hero = Pedang("Excalibur", 120.0)
    panah_hero = Panah("Busur Elang", 2)

    # Menguji Panah (serang berkali-kali)
    print("--- Simulasi Panah ---")
    panah_hero.serang()
    panah_hero.serang()
    panah_hero.serang() # Seharusnya habis

    # Menguji Pedang
    print("\n--- Simulasi Pedang ---")
    pedang_hero.serang()

    # Akses properti abstrak
    print("\n--- Status Senjata ---")
    pedang_hero.info_nama()
    print(f"Daya tahan pedang: {pedang_hero.ammo_atau_daya_tahan}")
    
    panah_hero.info_nama()
    print(f"Sisa ammo panah: {panah_hero.ammo_atau_daya_tahan}")
# Out:
# --- Simulasi Panah ---
# Panah Busur Elang melesat! Sisa anak panah: 1.
# Panah Busur Elang melesat! Sisa anak panah: 0.
# Amunisi Panah Busur Elang habis!
#
# --- Simulasi Pedang ---
# Pedang Excalibur menebas dengan bilah sepanjang 120.0 cm!
#
# --- Status Senjata ---
# Nama Senjata: Excalibur
# Daya tahan pedang: Daya tahan tinggi
# Nama Senjata: Busur Elang
# Sisa ammo panah: 0
